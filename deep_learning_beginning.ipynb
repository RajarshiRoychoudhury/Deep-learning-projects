# %%
import tensorflow as tf
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from tensorflow import keras
print(tf.__version__)
# Out:
# 1.14.0

# %% [markdown]
# IMPORTED ALL THE NECESSARY MODULES. NOW WE WILL BE WORKING ON FASHION MNIST

# %%
fashion_mnist=keras.datasets.fashion_mnist
(train_images,train_labels),(test_images,test_labels)=fashion_mnist.load_data()
train_images.shape
# Out:
# (60000, 28, 28)

# %%
plt.figure()
plt.imshow(train_images[0])
class_names=["Tshirt","Trouser","Pullover","Dress","Coat","Sandle","Tshirt",'sneaker',"bag","ankle boot"]
train_images=train_images/255
test_images=test_images/255

# %%
plt.figure(figsize=(10,10))
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(train_images[i])
  plt.grid(False)
  plt.xlabel(class_names[train_labels[i]])

# %%
model=keras.Sequential([keras.layers.Flatten(input_shape=(28,28)),keras.layers.Dense(128,activation=tf.nn.relu),keras.layers.Dense(128,activation=tf.nn.softmax)])
model.compile(optimizer=tf.train.AdamOptimizer(),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(train_images,train_label,epochs=5)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.2206 - acc: 0.9177
# Epoch 2/5
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.2115 - acc: 0.9203
# Epoch 3/5
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.2079 - acc: 0.9221
# Epoch 4/5
# 60000/60000 [==============================] - 4s 70us/sample - loss: 0.2006 - acc: 0.9246
# Epoch 5/5
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.1956 - acc: 0.9272

# %%
test_loss,test_acc=model.evaluate(test_images,test_labels)
print("Test accuray",test_acc)
# Out:
# 10000/10000 [==============================] - 0s 39us/sample - loss: 0.3689 - acc: 0.8783
# Test accuray 0.8783
